# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n-seg.pt")

# Train the model
train_results = model.train(
    data="E:\\yolo11\\custom_instance_seg\\BRAINTUMOR\\data.yaml",  # path to dataset YAML
    epochs=10,  # number of training epochs
    imgsz=640,  # training image size
    device=0,  # device to run on, i.e. device=0 or device=0,1,2,3 or device=cpu
)
# Out:
# ...
# 100%|█████████████████████████████████████████████████████████| 5.90M/5.90M [00:00<00:00, 11.1MB/s]
# New https://pypi.org/project/ultralytics/8.3.6 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.5  Python-3.10.11 torch-2.4.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3090, 24576MiB)
# ...

# %%
model = YOLO('runs\\segment\\train\\weights\\best.pt')
results = model("test_images/1.jpg", save=True)
results[0].show()
# Out:
# image 1/1 E:\yolo11\custom_instance_seg\test_images\1.jpg: 640x640 1 tumor, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\segment\predict
# <PIL.Image.Image image mode=RGB size=640x640>

# %%
model = YOLO('runs\\segment\\train\\weights\\best.pt')
results = model("test_images", save=True)
# Out:
# image 1/3 E:\yolo11\custom_instance_seg\test_images\1.jpg: 640x640 1 tumor, 16.0ms
# image 2/3 E:\yolo11\custom_instance_seg\test_images\2.jpg: 640x640 1 tumor, 28.0ms
# image 3/3 E:\yolo11\custom_instance_seg\test_images\3.jpg: 640x640 1 tumor, 16.0ms
# Speed: 2.3ms preprocess, 20.0ms inference, 8.7ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\segment\predict2
